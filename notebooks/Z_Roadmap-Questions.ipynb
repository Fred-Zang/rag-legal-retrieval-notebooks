# %% [markdown]
# <span style="color:#8B949E;">
# <b>Note de lecture</b> — Ce notebook présente mon <b>fil conducteur</b> : une roadmap “RAG juridique” posée dès le départ, ainsi qu’une liste de <b>questions de cadrage</b> notées au fur et à mesure.
# Il ne dépend pas d’un corpus particulier : l’objectif est de clarifier <b>l’ordre des priorités</b> (donnée & évaluation avant génération), et les décisions à prendre dès le début du projet (périmètre, usages, critères de succès, contraintes métier).
# </span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
